# %% [markdown]
# # Importing All necessary Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Importing Warnings

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Loading the Dataset

# %%
df=pd.read_csv('skyserver.csv')
df
# Out:
#              objid          ra        dec         u         g         r  \
# 0     1.237650e+18  183.531326   0.089693  19.47406  17.04240  15.94699
# 1     1.237650e+18  183.598371   0.135285  18.66280  17.21449  16.67637
# 2     1.237650e+18  183.680207   0.126185  19.38298  18.19169  17.47428
# 3     1.237650e+18  183.870529   0.049911  17.76536  16.60272  16.16116
# 4     1.237650e+18  183.883288   0.102557  17.55025  16.26342  16.43869
# ...            ...         ...        ...       ...       ...       ...
# 9995  1.237650e+18  131.316413  51.539547  18.81777  17.47053  16.91508
# 9996  1.237650e+18  131.306083  51.671341  18.27255  17.43849  17.07692
# 9997  1.237650e+18  131.552562  51.666986  18.75818  17.77784  17.51872
# 9998  1.237650e+18  131.477151  51.753068  18.88287  17.91068  17.53152
# 9999  1.237650e+18  131.665012  51.805307  19.27586  17.37829  16.30542
#
#              i         z   run  rerun  camcol  field     specobjid   class  \
# ...

# %%
df1=pd.read_csv('skyserver.csv')
df1
Redshift = df1["redshift"]

# %% [markdown]
# # Shape

# %%
df.shape
# Out:
# (10000, 18)

# %% [markdown]
# # Columns

# %%
df.columns
# Out:
# Index(['objid', 'ra', 'dec', 'u', 'g', 'r', 'i', 'z', 'run', 'rerun', 'camcol',
#        'field', 'specobjid', 'class', 'redshift', 'plate', 'mjd', 'fiberid'],
#       dtype='object')

# %% [markdown]
# # Datatypes

# %%
df.dtypes
# Out:
# objid        float64
# ra           float64
# dec          float64
# u            float64
# g            float64
# r            float64
# i            float64
# z            float64
# run            int64
# rerun          int64
# camcol         int64
# field          int64
# specobjid    float64
# class         object
# redshift     float64
# plate          int64
# mjd            int64
# fiberid        int64
# dtype: object

# %% [markdown]
# Observations:
#
# There are mixed datatypes. class is Object type and some are float types and some are int types.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 18 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   objid      10000 non-null  float64
#  1   ra         10000 non-null  float64
#  2   dec        10000 non-null  float64
#  3   u          10000 non-null  float64
#  4   g          10000 non-null  float64
#  5   r          10000 non-null  float64
#  6   i          10000 non-null  float64
#  7   z          10000 non-null  float64
#  8   run        10000 non-null  int64
#  9   rerun      10000 non-null  int64
#  10  camcol     10000 non-null  int64
#  11  field      10000 non-null  int64
#  12  specobjid  10000 non-null  float64
#  13  class      10000 non-null  object
#  14  redshift   10000 non-null  float64
#  15  plate      10000 non-null  int64
#  16  mjd        10000 non-null  int64
#  17  fiberid    10000 non-null  int64
# dtypes: float64(10), int64(7), object(1)
# ...

# %% [markdown]
# Observations:
#
# Numeric features
#
# Numeric features = ['objid', 'ra', 'dec', 'u', 'g', 'r', 'i', 'z', 'run', 'rerun', 'camcol',
#        'field', 'specobjid','redshift', 'plate', 'mjd', 'fiberid']
#
# Catagorical features
#
# Catagorical features =['class']

# %% [markdown]
# # Missing Values

# %%
df.isnull().values.any()
# Out:
# False

# %% [markdown]
# There are no missing values

# %% [markdown]
# ### Missing values column wise

# %%
df.isnull().sum()
# Out:
# objid        0
# ra           0
# dec          0
# u            0
# g            0
# r            0
# i            0
# z            0
# run          0
# rerun        0
# camcol       0
# field        0
# specobjid    0
# class        0
# redshift     0
# plate        0
# mjd          0
# fiberid      0
# dtype: int64

# %% [markdown]
# ### Missing values via visualization

# %%
plt.figure(figsize=(8,6))
sns.heatmap(df.isnull(),yticklabels=False,cbar=False)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Observations:
#
# The summary shows that there are no missing values in any column.

# %% [markdown]
# # Exploratory the catagorical columns

# %% [markdown]
# ### Printing the object data types and their unique values

# %%
for column in df.columns:
    if df[column].dtype==object:
        print(str(column) + ':' + str(df[column].unique()))
        print(df[column].value_counts())
        print('**********************************************************************************')
        print("\n")
# Out:
# class:['STAR' 'GALAXY' 'QSO']
# GALAXY    4998
# STAR      4152
# QSO        850
# Name: class, dtype: int64
# **********************************************************************************

# %% [markdown]
# Observations:
#
#        This is the summary of catagorical columns.
#
#         1. Class column is object type. Three values are present here. The values are :
#
#             1. GALAXY ----- It has been appeared for 4998 times
#
#             2. STAR   ----- It has been appeared for 4152 times
#
#             3. QSO    ----- It has been appeared for 850 times

# %% [markdown]
# ### For analyzing the data with target i.e. class we have to change class into numeric type.

# %%
df['class']=df['class'].map({'GALAXY':0,'STAR':1,'QSO':2})
df['class'].dtypes
# Out:
# dtype('int64')

# %%
df['class'].unique()
# Out:
# array([1, 0, 2], dtype=int64)

# %% [markdown]
# Observations:
#
#          Here,
#
#          0 stands for GALAXY
#
#          1 stands for STAR.
#
#          2 stands for QSO

# %% [markdown]
# # Summary Statistics

# %%
df.columns
# Out:
# Index(['objid', 'ra', 'dec', 'u', 'g', 'r', 'i', 'z', 'run', 'rerun', 'camcol',
#        'field', 'specobjid', 'class', 'redshift', 'plate', 'mjd', 'fiberid'],
#       dtype='object')

# %%
df.describe()
# Out:
#               objid            ra           dec             u             g  \
# count  1.000000e+04  10000.000000  10000.000000  10000.000000  10000.000000
# mean   1.237650e+18    175.529987     14.836148     18.619355     17.371931
# std    1.577039e+05     47.783439     25.212207      0.828656      0.945457
# min    1.237650e+18      8.235100     -5.382632     12.988970     12.799550
# 25%    1.237650e+18    157.370946     -0.539035     18.178035     16.815100
# 50%    1.237650e+18    180.394514      0.404166     18.853095     17.495135
# 75%    1.237650e+18    201.547279     35.649397     19.259232     18.010145
# max    1.237650e+18    260.884382     68.542265     19.599900     19.918970
#
#                   r             i             z           run    rerun  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.0
# mean      16.840963     16.583579     16.422833    981.034800    301.0
# ...

# %% [markdown]
# Observations:
#
#     1.Maximum 'objid', 'ra', 'dec', 'u', 'g', 'r', 'i', 'z', 'run', 'rerun', 'camcol','field', 'specobjid', 'class','redshift', 'plate', 'mjd', 'fiberid' are :         1.237650e+18,260.884382,68.542265,19.599900,19.918970,24.802040,28.179630,22.833060,1412.000000,301.0,6.000000,768.000000,9.468830e+18,	2.000000,5.353854,8410.000000,57481.000000,1000.000000
#
#     2. Minimum 'objid', 'ra', 'dec', 'u', 'g', 'r', 'i', 'z', 'run', 'rerun', 'camcol',
#        'field', 'specobjid', 'class', 'redshift', 'plate', 'mjd', 'fiberid' are 1.237650e+18,	8.235100,	-5.382632,	12.988970,	12.799550,	12.431600,	11.947210,	11.610410,	308.000000,	301.0,	1.000000,	11.000000,	2.995780e+17,	0.000000,	-0.004136,	266.000000,	51578.000000,	1.000000
#
#     3.dec,(i,z),run,field,redshift,plate,mjd,fiberid  mean is greater than median therefore data is right skewed for these attributes. (i,z) columns have very less difference with median.
#
#     4. ra,(u,g,r),camcol,specobjid,class, median is greater than mean therefre data is left skewed for these attributes.(u,g,r) have very less difference with median.
#
#     5. The difference between 75% and maximum is higher in run,field,specobjid,redshift,plate,mjd and fiberid columns therefore outliers are present in these columns.

# %% [markdown]
# # Correlation

# %% [markdown]
# ### Correlation only with target variable

# %%
plt.figure(figsize=(16,6))
df.drop('class',axis=1).corrwith(df['class']).plot(kind='bar',grid=True)
plt.xticks(rotation=20)
plt.title("Correlation with Target Variable")
# Out:
# Text(0.5, 1.0, 'Correlation with Target Variable')

# %%
df[df.columns[1:]].corr()['class'][:]
# Out:
# ra          -0.023999
# dec          0.001451
# u           -0.122010
# g            0.200748
# r            0.344900
# i            0.417631
# z            0.465475
# run         -0.017958
# rerun             NaN
# camcol       0.000823
# field        0.008897
# specobjid    0.414677
# class        1.000000
# redshift     0.492611
# plate        0.414678
# mjd          0.448355
# fiberid      0.067150
# Name: class, dtype: float64

# %% [markdown]
# Findings:
#
#     1. Negative correlation : ra,u,run,objid
#
#     2. Positive correlation : dec,g, r, i, z,camcol, field, specobjid, redshift, plate, mjd, fiberid
#
#     3. No correlation : rerun . Because there is only one constant value present.
#
#     4. Strong Correlationship : g,r, i,u, z,specobjid, redshift, plate, mjd
#
#     5. Weak Correlation :dec, ra,run,camcol,objid field,fiberid. If these columns have outliers then these columns should be deleted.

# %% [markdown]
# # Heatmap

# %%
plt.figure(figsize=(20,10))
sns.heatmap(df.corr(),annot=True,fmt='.0%',cmap='cool')
plt.show()

# %% [markdown]
# Observations :
#
#     1. From the previous line we have already known about the correlation with target variable. Now, Let me check the other observations.
#
#     2. Good Correlationship with other variables except target variable :
#
#         1. (u,r,i,z) with g. The correlation is 85%,96%,91%,88%
#
#         2. (u,g,i,z) with r.
#
#         3. (u,g,r,z) with i.
#
#         4. (u,g,r,i) with z
#
#         5. (g,r,i,z) with u.
#
#         6. run and dec
#
#         7. field and ra
#
#         9. fiberid and camol
#
#         10.ra and field
#
#         11.specobjid and (plate,mjd)
#
#         12. plate and mjd

# %% [markdown]
# # Data Visualizations

# %% [markdown]
# Our feature variable of interest is class
#
# We already change it to integer valued as it contains three numbers 0,1 and 2
#
#      0 stands for GALAXY
#
#      1 stands for STAR.
#
#      2 stands for QSO

# %% [markdown]
# # Univariate Analysis

# %% [markdown]
# # U

# %%
df['u'].hist()
# Out:
# <AxesSubplot:>

# %%
u_amount=df['u'].hist(bins=70)
mean_val=np.mean(df['u'])
plt.axvline(mean_val,linewidth=4,color='red',label='u_mean')
plt.xlabel('u')
plt.ylabel('count')
plt.legend()
plt.show()

# %% [markdown]
# # g

# %%
g_amount=df['g'].hist(bins=70)
mean_val=np.mean(df['g'])
plt.axvline(mean_val,linewidth=4,color='red',label='g_mean')
plt.xlabel('u')
plt.ylabel('count')
plt.legend()
plt.show()

# %% [markdown]
# # r

# %%
r_amount=df['r'].hist(bins=70)
mean_val=np.mean(df['r'])
plt.axvline(mean_val,linewidth=4,color='red',label='r_mean')
plt.xlabel('r')
plt.ylabel('count')
plt.legend()
plt.show()

# %% [markdown]
# # i

# %%
i_amount=df['i'].hist(bins=70)
mean_val=np.mean(df['i'])
plt.axvline(mean_val,linewidth=4,color='red',label='i_mean')
plt.xlabel('i')
plt.ylabel('count')
plt.legend()
plt.show()

# %% [markdown]
# # z

# %%
z_amount=df['z'].hist(bins=70)
mean_val=np.mean(df['z'])
plt.axvline(mean_val,linewidth=4,color='red',label='z_mean')
plt.xlabel('z')
plt.ylabel('count')
plt.legend()
plt.show()

# %% [markdown]
# # run

# %%
plt.subplots(figsize=(20,6))
sns.countplot(x="run",data=df)
plt.title("Run")
plt.xticks(rotation=20)
plt.show()

print(df.run.value_counts())
# Out:
# 756     3060
# 752     2086
# 1345     915
# 1350     540
# 1140     527
# 745      453
# 1035     396
# 1412     347
# 1302     246
# 1331     245
# 1231     245
# 1334     212
# 1239     197
# 1336     182
# 1404     137
# 1045     112
# 1402      49
# 308       31
# 1411      10
# 1356       4
# 727        4
# 1119       1
# 1332       1
# Name: run, dtype: int64

# %% [markdown]
# # camol

# %%
plt.subplots(figsize=(15,6))
sns.countplot(x="camcol",data=df)
plt.title("camcol")
plt.xticks(rotation=20)
plt.show()

print(df.camcol.value_counts())
# Out:
# 4    1834
# 5    1827
# 6    1769
# 2    1712
# 3    1560
# 1    1298
# Name: camcol, dtype: int64

# %% [markdown]
# # field

# %%
field_amount=df['field'].hist(bins=70)
mean_val=np.mean(df['field'])
plt.axvline(mean_val,linewidth=4,color='red',label='field_mean')
plt.xlabel('field')
plt.ylabel('count')
plt.legend()
plt.show()

# %% [markdown]
# # specobjid

# %%
specobjid_amount=df['specobjid'].hist(bins=70)
mean_val=np.mean(df['specobjid'])
plt.axvline(mean_val,linewidth=4,color='red',label='specobjid_mean')
plt.xlabel('specobjid')
plt.ylabel('count')
plt.legend()
plt.show()

# %% [markdown]
# # plate

# %%
plate_amount=df['plate'].hist(bins=70)
mean_val=np.mean(df['plate'])
plt.axvline(mean_val,linewidth=4,color='red',label='plate_mean')
plt.xlabel('plate')
plt.ylabel('count')
plt.legend()
plt.show()

# %% [markdown]
# # mjd

# %%
i_amount=df['mjd'].hist(bins=70)
mean_val=np.mean(df['mjd'])
plt.axvline(mean_val,linewidth=4,color='red',label='mjd_mean')
plt.xlabel('mjd')
plt.ylabel('count')
plt.legend()
plt.show()

# %% [markdown]
# # fiberid

# %%
fiberid_amount=df['fiberid'].hist(bins=70)
mean_val=np.mean(df['fiberid'])
plt.axvline(mean_val,linewidth=4,color='red',label='fiberid_mean')
plt.xlabel('fiberid')
plt.ylabel('count')
plt.legend()
plt.show()

# %% [markdown]
# # Bivariate Analysis

# %%
df.nunique()
# Out:
# u            9730
# g            9817
# r            9852
# i            9890
# z            9896
# run            23
# camcol          6
# field         703
# specobjid    6349
# class           3
# plate         487
# mjd           355
# fiberid       892
# dtype: int64

# %% [markdown]
# # u vs class

# %%
plt.figure(figsize=(8,4))
sns.lmplot(x='u',y='class',fit_reg=False,data=df)
plt.show()

# %% [markdown]
# # g vs class

# %%
plt.figure(figsize=(8,4))
sns.lmplot(x='g',y='class',fit_reg=False,data=df)
plt.show()

# %% [markdown]
# # r vs class

# %%
plt.figure(figsize=(8,4))
sns.lmplot(x='r',y='class',fit_reg=False,data=df)
plt.show()

# %% [markdown]
# # i vs class

# %%
plt.figure(figsize=(8,4))
sns.lmplot(x='i',y='class',fit_reg=False,data=df)
plt.show()

# %% [markdown]
# # z vs class

# %%
plt.figure(figsize=(8,4))
sns.lmplot(x='z',y='class',fit_reg=False,data=df)
plt.show()

# %% [markdown]
# # run vs class

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(20,6))
total = float(len(df))
ax = sns.countplot(x="run", hue="class", data=df)
plt.title('Data provided for each event', fontsize=20)
for p in ax.patches:
    percentage = '{:.1f}%'.format(100 * p.get_height()/total)
    x = p.get_x() + p.get_width()
    y = p.get_height()
    ax.annotate(percentage, (x, y),ha='center')
plt.show()

# %% [markdown]
# # camcol vs class

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(20,6))
total = float(len(df))
ax = sns.countplot(x="camcol", hue="class", data=df)
plt.title('Data provided for each event', fontsize=20)
for p in ax.patches:
    percentage = '{:.1f}%'.format(100 * p.get_height()/total)
    x = p.get_x() + p.get_width()
    y = p.get_height()
    ax.annotate(percentage, (x, y),ha='center')
plt.show()

# %% [markdown]
# # field vs class

# %%
plt.figure(figsize=(8,4))
sns.lmplot(x='field',y='class',fit_reg=False,data=df)
plt.show()

# %% [markdown]
# # specobjid vs class

# %%
plt.figure(figsize=(8,4))
sns.lmplot(x='specobjid',y='class',fit_reg=False,data=df)
plt.show()

# %% [markdown]
# # plate vs class

# %%
plt.figure(figsize=(8,4))
sns.lmplot(x='plate',y='class',fit_reg=False,data=df)
plt.show()

# %% [markdown]
# # mjd vs class

# %%
plt.figure(figsize=(8,4))
sns.lmplot(x='z',y='class',fit_reg=False,data=df)
plt.show()

# %% [markdown]
# # fiberid vs class

# %%
plt.figure(figsize=(8,4))
sns.lmplot(x='fiberid',y='class',fit_reg=False,data=df)
plt.show()

# %% [markdown]
# # Checking Unique values

# %%
df.nunique()
# Out:
# objid            1
# ra           10000
# dec          10000
# u             9730
# g             9817
# r             9852
# i             9890
# z             9896
# run             23
# rerun            1
# camcol           6
# field          703
# specobjid     6349
# class            3
# redshift      9637
# plate          487
# mjd            355
# fiberid        892
# dtype: int64

# %% [markdown]
# Observations :
#
#     1. objid and rerun has only one unique value. So, these two columns shold be deleted. It will not effect our dataset.
#
#     2. all the values of ra,dec column are unique. These two columns can also be deleted. It will not effect our dataset.
#
#     3. u,g,r,i,z having a lot of unique values. But all the values are not unique.

# %% [markdown]
# # Check Outliers

# %%
df.plot(kind='box',subplots=True,layout=(4,5),color='green',figsize=(13,13))
plt.tight_layout()

# %% [markdown]
# Observations :
#
#     ra,u,g,r,i,z,field,specobjid,redshift,plate,fiberid having outliers

# %% [markdown]
# # Check outliers Individually

# %%
df['objid'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['ra'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['dec'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['u'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['g'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['r'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['i'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['z'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['run'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['rerun'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['camcol'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['field'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['specobjid'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['class'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['redshift'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['plate'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['mjd'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['fiberid'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Dropping columns

# %% [markdown]
# 1. These objid,rerun,ra,dec  four colums will be deleted. Because there are either one single value or all the values are unique.
#
# 2. fiberid and field having outliers. But there are very few outliers. So, we will keep these two columns.

# %%
df.drop(['objid','rerun','ra','dec'], axis = 1,inplace=True)

# %%
df.head()
# Out:
#           u         g         r         i         z  run  camcol  field  \
# 0  19.47406  17.04240  15.94699  15.50342  15.22531  752       4    267
# 1  18.66280  17.21449  16.67637  16.48922  16.39150  752       4    267
# 2  19.38298  18.19169  17.47428  17.08732  16.80125  752       4    268
# 3  17.76536  16.60272  16.16116  15.98233  15.90438  752       4    269
# 4  17.55025  16.26342  16.43869  16.55492  16.61326  752       4    269
#
#       specobjid  class  redshift  plate    mjd  fiberid
# 0  3.722360e+18      1 -0.000009   3306  54922      491
# 1  3.638140e+17      1 -0.000055    323  51615      541
# 2  3.232740e+17      0  0.123111    287  52023      513
# 3  3.722370e+18      1 -0.000111   3306  54922      510
# 4  3.722370e+18      1  0.000590   3306  54922      512

# %% [markdown]
# # Skewness

# %% [markdown]
# ### Check the distribution of Skewness

# %%
for col in df.describe().columns:           #We have used df.describe() because we want the skewness only for numeric
    sns.distplot(df[col],color='r')
    plt.show()

# %%
df.skew()
# Out:
# u           -1.219795
# g           -0.536293
# r           -0.021673
# i            0.286442
# z            0.214313
# run          0.412555
# camcol      -0.100220
# field        0.249795
# specobjid    1.794627
# class        0.641904
# redshift     4.265729
# plate        1.794609
# mjd          1.039610
# fiberid      0.308053
# dtype: float64

# %% [markdown]
# ### Treating Skewness via root method and cube root method

# %%
df.skew()
for col in df.skew().index:
    if col in df.describe().columns:
        if df[col].skew()>0.55:
            df[col]=np.sqrt(df[col])
        if df[col].skew()<-0.55:
            df[col]=np.cbrt(df[col])

# %%
df.skew()
# Out:
# u           -1.315798
# g           -0.536293
# r           -0.021673
# i            0.286442
# z            0.214313
# run          0.412555
# camcol      -0.100220
# field        0.249795
# specobjid    1.093905
# class        0.138669
# redshift     2.268173
# plate        1.093870
# mjd          1.025184
# fiberid      0.308053
# dtype: float64

# %%
for col in df.describe().columns:           #We have used df.describe() because we want the skewness only for numeric
    sns.distplot(df[col],color='r')
    plt.show()

# %%
df.head()
# Out:
#           u         g         r         i         z  run  camcol  field  \
# 0  2.690412  17.04240  15.94699  15.50342  15.22531  752       4    267
# 1  2.652522  17.21449  16.67637  16.48922  16.39150  752       4    267
# 2  2.686211  18.19169  17.47428  17.08732  16.80125  752       4    268
# 3  2.609304  16.60272  16.16116  15.98233  15.90438  752       4    269
# 4  2.598730  16.26342  16.43869  16.55492  16.61326  752       4    269
#
#       specobjid  class  redshift      plate         mjd  fiberid
# 0  1.929342e+09    1.0       NaN  57.497826  234.354432      491
# 1  6.031700e+08    1.0       NaN  17.972201  227.189348      541
# 2  5.685719e+08    0.0  0.350872  16.941074  228.085510      513
# 3  1.929344e+09    1.0       NaN  57.497826  234.354432      510
# 4  1.929344e+09    1.0  0.024297  57.497826  234.354432      512

# %%
df.isnull().any()
# Out:
# u            False
# g            False
# r            False
# i            False
# z            False
# run          False
# camcol       False
# field        False
# specobjid    False
# class        False
# redshift      True
# plate        False
# mjd          False
# fiberid      False
# dtype: bool

# %% [markdown]
# Now, Null values are present in the redshift column

# %% [markdown]
# ### Drop this column

# %%
df.drop(['redshift'], axis = 1,inplace=True)

# %%
#df=df.join(Redshift)
#df

# %%
df.shape
# Out:
# (10000, 13)

# %% [markdown]
# # Removing Outliers

# %% [markdown]
# ### z-score

# %%
from scipy.stats import zscore
import numpy as np
z=np.abs(zscore(df))
threshold=3
df_new=df[(z<3).all(axis=1)]

# %% [markdown]
# ### Checking shape

# %%
print(df.shape,"\t\t",df_new.shape)
# Out:
# (10000, 13) 		 (9802, 13)

# %% [markdown]
# After removing outliers no rows are present. So, we can not accept it.

# %% [markdown]
# ### IQR

# %%
q1=df.quantile(0.25)
q3=df.quantile(0.75)
IQR=q3-q1
print(IQR)
df_new1=df[~((df<(q1-1.5*IQR))|(df>(q3+1.5*IQR))).any(axis=1)]
print(df_new1.shape)
# Out:
# u            5.112910e-02
# g            1.195045e+00
# r            1.339343e+00
# i            1.404845e+00
# z            1.523162e+00
# run          5.790000e+02
# camcol       3.000000e+00
# field        2.300000e+02
# specobjid    1.115267e+09
# class        1.000000e+00
# plate        3.323721e+01
# mjd          5.568089e+00
# fiberid      3.232500e+02
# dtype: float64
# (9557, 13)

# %% [markdown]
# ### Percentage Loss

# %%
data_loose=(443/10000)*100
print(data_loose)
# Out:
# 4.43

# %% [markdown]
# Using through IQR 5% data has been losed. So, we will accept IQR.

# %%
df_new1.shape
# Out:
# (9557, 13)

# %% [markdown]
# # Model Training

# %%
df_new1.head()
# Out:
#           u         g         r         i         z  run  camcol  field  \
# 0  2.690412  17.04240  15.94699  15.50342  15.22531  752       4    267
# 1  2.652522  17.21449  16.67637  16.48922  16.39150  752       4    267
# 2  2.686211  18.19169  17.47428  17.08732  16.80125  752       4    268
# 3  2.609304  16.60272  16.16116  15.98233  15.90438  752       4    269
# 4  2.598730  16.26342  16.43869  16.55492  16.61326  752       4    269
#
#       specobjid  class      plate         mjd  fiberid
# 0  1.929342e+09    1.0  57.497826  234.354432      491
# 1  6.031700e+08    1.0  17.972201  227.189348      541
# 2  5.685719e+08    0.0  16.941074  228.085510      513
# 3  1.929344e+09    1.0  57.497826  234.354432      510
# 4  1.929344e+09    1.0  57.497826  234.354432      512

# %% [markdown]
# ### Spilitting the data into input and output variable

# %%
x=df_new1.drop(columns=['class'],axis=1)
x.head()
# Out:
#           u         g         r         i         z  run  camcol  field  \
# 0  2.690412  17.04240  15.94699  15.50342  15.22531  752       4    267
# 1  2.652522  17.21449  16.67637  16.48922  16.39150  752       4    267
# 2  2.686211  18.19169  17.47428  17.08732  16.80125  752       4    268
# 3  2.609304  16.60272  16.16116  15.98233  15.90438  752       4    269
# 4  2.598730  16.26342  16.43869  16.55492  16.61326  752       4    269
#
#       specobjid      plate         mjd  fiberid
# 0  1.929342e+09  57.497826  234.354432      491
# 1  6.031700e+08  17.972201  227.189348      541
# 2  5.685719e+08  16.941074  228.085510      513
# 3  1.929344e+09  57.497826  234.354432      510
# 4  1.929344e+09  57.497826  234.354432      512

# %%
y=df_new1['class']
y.head()
# Out:
# 0    1.0
# 1    1.0
# 2    0.0
# 3    1.0
# 4    1.0
# Name: class, dtype: float64

# %% [markdown]
# ### Checking the shape of the input and output variable

# %%
print(x.shape,'\t\t', y.shape)
# Out:
# (9557, 12) 		 (9557,)

# %% [markdown]
# # Scaling in input variables

# %% [markdown]
# ### As after using the skewness treatment null values have been appeared in the redshift column that's why I have added the new redshit column from the default dataset

# %%
x=x.join(Redshift)
x
# Out:
#              u         g         r         i         z   run  camcol  field  \
# 0     2.690412  17.04240  15.94699  15.50342  15.22531   752       4    267
# 1     2.652522  17.21449  16.67637  16.48922  16.39150   752       4    267
# 2     2.686211  18.19169  17.47428  17.08732  16.80125   752       4    268
# 3     2.609304  16.60272  16.16116  15.98233  15.90438   752       4    269
# 4     2.598730  16.26342  16.43869  16.55492  16.61326   752       4    269
# ...        ...       ...       ...       ...       ...   ...     ...    ...
# 9995  2.659843  17.47053  16.91508  16.68305  16.50570  1345       3    161
# 9996  2.633903  17.43849  17.07692  16.71661  16.69897  1345       3    162
# 9997  2.657033  17.77784  17.51872  17.43302  17.42048  1345       3    162
# 9998  2.662907  17.91068  17.53152  17.36284  17.13988  1345       3    163
# 9999  2.681254  17.37829  16.30542  15.83548  15.50588  1345       3    163
#
# ...

# %% [markdown]
# ### Convert all the x values to float type and all the y values to integer type

# %%
x = x.astype(float)
y=y.astype(int)

# %% [markdown]
# ### Check is there any null value or not

# %%
np.any(np.isnan(x))
# Out:
# False

# %% [markdown]
# ### Check is there any infinite value or not

# %%
np.all(np.isfinite(x))
# Out:
# True

# %% [markdown]
# There are infinite values present in the dataset. So, we need to fix it

# %% [markdown]
# ### Change to DataFrame

# %%
x=pd.DataFrame(x)
x.isnull().values.any()
# Out:
# False

# %%
x.shape
# Out:
# (9557, 13)

# %%
x.head()
# Out:
#           u         g         r         i         z    run  camcol  field  \
# 0  2.690412  17.04240  15.94699  15.50342  15.22531  752.0     4.0  267.0
# 1  2.652522  17.21449  16.67637  16.48922  16.39150  752.0     4.0  267.0
# 2  2.686211  18.19169  17.47428  17.08732  16.80125  752.0     4.0  268.0
# 3  2.609304  16.60272  16.16116  15.98233  15.90438  752.0     4.0  269.0
# 4  2.598730  16.26342  16.43869  16.55492  16.61326  752.0     4.0  269.0
#
#       specobjid      plate         mjd  fiberid  redshift
# 0  1.929342e+09  57.497826  234.354432    491.0 -0.000009
# 1  6.031700e+08  17.972201  227.189348    541.0 -0.000055
# 2  5.685719e+08  16.941074  228.085510    513.0  0.123111
# 3  1.929344e+09  57.497826  234.354432    510.0 -0.000111
# 4  1.929344e+09  57.497826  234.354432    512.0  0.000590

# %% [markdown]
# ### StandardScaler

# %%
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
x=ss.fit_transform(x)

# %%
x=pd.DataFrame(x)
x.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0  1.080774 -0.470566 -0.978038 -1.083737 -1.115136 -0.840466  0.209386
# 1 -0.037142 -0.265607 -0.223500 -0.130054 -0.061458 -0.840466  0.209386
# 2  0.956832  0.898241  0.601931  0.448560  0.308760 -0.840466  0.209386
# 3 -1.312225 -0.994226 -0.756481 -0.620430 -0.501581 -0.840466  0.209386
# 4 -1.624206 -1.398334 -0.469378 -0.066495  0.138907 -0.840466  0.209386
#
#          7         8         9         10        11        12
# 0 -0.212732  1.264807  1.264802  1.337389  0.676069 -0.377744
# 1 -0.212732 -0.704839 -0.704913 -0.867112  0.919977 -0.377862
# 2 -0.206537 -0.756224 -0.756298 -0.591387  0.783389 -0.061314
# 3 -0.200342  1.264811  1.264802  1.337389  0.768754 -0.378005
# 4 -0.200342  1.264811  1.264802  1.337389  0.778510 -0.376203

# %% [markdown]
# ### spliting the data into training and testing set

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=42,stratify=y)

# %% [markdown]
# ### Checking the shape

# %%
print(x_train.shape,'\t\t',x_test.shape)
# Out:
# (7645, 13) 		 (1912, 13)

# %%
print(y_train.shape,'\t\t',y_test.shape)
# Out:
# (7645,) 		 (1912,)

# %% [markdown]
# # Importing all the model Library

# %%
# Libraries for data modelling
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier

#Importinf boosting models
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import ExtraTreesClassifier

#Importing error metrics
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
from sklearn.model_selection import GridSearchCV,cross_val_score

# %% [markdown]
# # All algorithms are in one code

# %%
model=[LogisticRegression(),GaussianNB(),SVC(),DecisionTreeClassifier(),KNeighborsClassifier(),RandomForestClassifier(),AdaBoostClassifier(),GradientBoostingClassifier(),BaggingClassifier(),ExtraTreesClassifier()]

for m in model:
    m.fit(x_train,y_train)
    m.score(x_train,y_train)
    predm=m.predict(x_test)
    print("\033[1m"+ 'Accuracy score of',m,'is : ' + "\033[0m" )  # Make the line bold
    print(accuracy_score(y_test,predm))
    print(confusion_matrix(y_test,predm))
    print(classification_report(y_test,predm))
    print('*******************************************************************')
    print('\n')
# Out:
# Accuracy score of LogisticRegression() is :
# 0.9314853556485355
# [[915  66]
#  [ 65 866]]
#               precision    recall  f1-score   support
#
#            0       0.93      0.93      0.93       981
#            1       0.93      0.93      0.93       931
#
#     accuracy                           0.93      1912
#    macro avg       0.93      0.93      0.93      1912
# weighted avg       0.93      0.93      0.93      1912
#
# *******************************************************************
#
#
# Accuracy score of GaussianNB() is :
# 0.8875523012552301
# [[944  37]
#  [178 753]]
#               precision    recall  f1-score   support
#
#            0       0.84      0.96      0.90       981
#            1       0.95      0.81      0.88       931
#
#     accuracy                           0.89      1912
#    macro avg       0.90      0.89      0.89      1912
# weighted avg       0.90      0.89      0.89      1912
#
# ...

# %% [markdown]
# Findingd :
#     1. Accuracy score of LogisticRegression() is : 0.9314853556485355
#
#     2. Accuracy score of GaussianNB() is : 0.8875523012552301
#
#     3. Accuracy score of SVC() is : 0.9382845188284519
#
#     4. Accuracy score of DecisionTreeClassifier() is : 0.9884937238493724
#
#     5. Accuracy score of KNeighborsClassifier() is : 0.9095188284518828
#
#     6. Accuracy score of RandomForestClassifier() is : 0.9884937238493724
#
#     7. Accuracy score of AdaBoostClassifier() is : 0.9879707112970711
#
#     8. Accuracy score of GradientBoostingClassifier() is : 0.9879707112970711
#
#     9. Accuracy score of BaggingClassifier() is : 0.9879707112970711
#
#     10. Accuracy score of ExtraTreesClassifier() is : 0.981694560669456

# %% [markdown]
# We have got good accuracy score using DecisionTreeClassifier(),RandomForestClassifier(),AdaBoostClassifier(),GradientBoostingClassifier(),BaggingClassifier(),ExtraTreesClassifier()

# %% [markdown]
# Let me try to find the best parameter using these algorithms

# %% [markdown]
# # Finding the best Parameters

# %% [markdown]
# ### Using GridSearchCV to find the best parameter in RandomForestClassifier()

# %%
parameters={'criterion':["gini", "entropy"],'random_state':range(42,100)}
rf=RandomForestClassifier()

clf=GridSearchCV(rf,parameters)
clf.fit(x,y)
print(clf.best_params_)
# Out:
# {'criterion': 'entropy', 'random_state': 47}

# %% [markdown]
# ### Using GridSearchCV to find the best parameter in AdaBoostClassifier()

# %%
parameters={'random_state':range(42,100)}
ad=RandomForestClassifier()

clf=GridSearchCV(ad,parameters)
clf.fit(x,y)
print(clf.best_params_)
# Out:
# {'random_state': 72}

# %% [markdown]
# ### Using GridSearchCV to find the best parameter in GradientBoostingClassifier()

# %%
parameters={'max_features':['auto','sqrt','log2'],'random_state':range(42,100)}
gd=RandomForestClassifier()

clf=GridSearchCV(gd,parameters)
clf.fit(x,y)
print(clf.best_params_)
# Out:
# {'max_features': 'auto', 'random_state': 72}

# %% [markdown]
# ### Using GridSearchCV to find the best parameter in BaggingClassifier()

# %%
parameters={'random_state':range(42,100)}
bc=RandomForestClassifier()

clf=GridSearchCV(bc,parameters)
clf.fit(x,y)
print(clf.best_params_)
# Out:
# {'random_state': 72}

# %% [markdown]
# ### Using GridSearchCV to find the best parameter in ExtraTreesClassifier()

# %%
parameters={'random_state':range(42,100)}
ec=RandomForestClassifier()

clf=GridSearchCV(ec,parameters)
clf.fit(x,y)
print(clf.best_params_)
# Out:
# {'random_state': 72}

# %% [markdown]
# ### Using GridSearchCV to find the best parameter in DecisionTreeClassifier()

# %%
parameters={'random_state':range(42,100)}
dtc=RandomForestClassifier()

clf=GridSearchCV(dtc,parameters)
clf.fit(x,y)
print(clf.best_params_)
# Out:
# {'random_state': 72}

# %% [markdown]
# # Using Best Parameter

# %% [markdown]
# ### RandomForestClassifier() with best parameter

# %%
rf=RandomForestClassifier(criterion= 'entropy',random_state=42)
rf.fit(x_train,y_train)
rf.score(x_train,y_train)
predrf=rf.predict(x_test)
print('Accuracy score of',rf,'is : ')
print(accuracy_score(y_test,predrf))
print(confusion_matrix(y_test,predrf))
print(classification_report(y_test,predrf))
# Out:
# Accuracy score of RandomForestClassifier(criterion='entropy', random_state=42) is :
# 0.9890167364016736
# [[969  12]
#  [  9 922]]
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       981
#            1       0.99      0.99      0.99       931
#
#     accuracy                           0.99      1912
#    macro avg       0.99      0.99      0.99      1912
# weighted avg       0.99      0.99      0.99      1912

# %% [markdown]
# ### AdaBoostClassifier() with best parameter

# %%
ad=AdaBoostClassifier(random_state=72)
ad.fit(x_train,y_train)
ad.score(x_train,y_train)
predad=ad.predict(x_test)
print('Accuracy score of',ad,'is : ')
print(accuracy_score(y_test,predad))
print(confusion_matrix(y_test,predad))
print(classification_report(y_test,predad))
# Out:
# Accuracy score of AdaBoostClassifier(random_state=72) is :
# 0.9879707112970711
# [[971  10]
#  [ 13 918]]
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       981
#            1       0.99      0.99      0.99       931
#
#     accuracy                           0.99      1912
#    macro avg       0.99      0.99      0.99      1912
# weighted avg       0.99      0.99      0.99      1912

# %% [markdown]
# ### GradientBoostingClassifier() with best parameter

# %%
gd=GradientBoostingClassifier(max_features= 'auto',random_state=72)
gd.fit(x_train,y_train)
gd.score(x_train,y_train)
predgd=gd.predict(x_test)
print('Accuracy score of',gd,'is : ')
print(accuracy_score(y_test,predgd))
print(confusion_matrix(y_test,predgd))
print(classification_report(y_test,predgd))
# Out:
# Accuracy score of GradientBoostingClassifier(max_features='auto', random_state=72) is :
# 0.9879707112970711
# [[970  11]
#  [ 12 919]]
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       981
#            1       0.99      0.99      0.99       931
#
#     accuracy                           0.99      1912
#    macro avg       0.99      0.99      0.99      1912
# weighted avg       0.99      0.99      0.99      1912

# %% [markdown]
# ### BaggingClassifier() with best parameter

# %%
bc=BaggingClassifier(random_state=72)
bc.fit(x_train,y_train)
bc.score(x_train,y_train)
predbc=bc.predict(x_test)
print('Accuracy score of',bc,'is : ')
print(accuracy_score(y_test,predbc))
print(confusion_matrix(y_test,predbc))
print(classification_report(y_test,predbc))
# Out:
# Accuracy score of BaggingClassifier(random_state=72) is :
# 0.9890167364016736
# [[973   8]
#  [ 13 918]]
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       981
#            1       0.99      0.99      0.99       931
#
#     accuracy                           0.99      1912
#    macro avg       0.99      0.99      0.99      1912
# weighted avg       0.99      0.99      0.99      1912

# %% [markdown]
# ### ExtraTreesClassifier() with best parameter

# %%
ec=ExtraTreesClassifier(random_state=72)
ec.fit(x_train,y_train)
ec.score(x_train,y_train)
predec=ec.predict(x_test)
print('Accuracy score of',ec,'is : ')
print(accuracy_score(y_test,predec))
print(confusion_matrix(y_test,predec))
print(classification_report(y_test,predec))
# Out:
# Accuracy score of ExtraTreesClassifier(random_state=72) is :
# 0.9822175732217573
# [[964  17]
#  [ 17 914]]
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98       981
#            1       0.98      0.98      0.98       931
#
#     accuracy                           0.98      1912
#    macro avg       0.98      0.98      0.98      1912
# weighted avg       0.98      0.98      0.98      1912

# %% [markdown]
# ### DecisionTreeClassifier() with best parameter

# %%
dtc=DecisionTreeClassifier(random_state=72)
dtc.fit(x_train,y_train)
dtc.score(x_train,y_train)
preddtc=dtc.predict(x_test)
print('Accuracy score of',dtc,'is : ')
print(accuracy_score(y_test,preddtc))
print(confusion_matrix(y_test,preddtc))
print(classification_report(y_test,preddtc))
# Out:
# Accuracy score of DecisionTreeClassifier(random_state=72) is :
# 0.9879707112970711
# [[971  10]
#  [ 13 918]]
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99       981
#            1       0.99      0.99      0.99       931
#
#     accuracy                           0.99      1912
#    macro avg       0.99      0.99      0.99      1912
# weighted avg       0.99      0.99      0.99      1912

# %% [markdown]
# # Cross Validation score

# %% [markdown]
# ### Cross validate the RandomForestClassifier()

# %%
score=cross_val_score(rf,x,y,cv=10,scoring='accuracy')
print("model:",rf)
print("Score:",score)
print("Mean score:",score.mean())
print("Standard deviation:",score.std())
# Out:
# model: RandomForestClassifier(criterion='entropy', random_state=42)
# Score: [0.99372385 0.98535565 0.98849372 0.9958159  0.99058577 0.99476987
#  0.98535565 0.98429319 0.99162304 0.98638743]
# Mean score: 0.9896404083331507
# Standard deviation: 0.004039243717538677

# %% [markdown]
# ### Cross validate the AdaBoostClassifier()

# %%
score=cross_val_score(ad,x,y,cv=10,scoring='accuracy')
print("model:",ad)
print("Score:",score)
print("Mean score:",score.mean())
print("Standard deviation:",score.std())
# Out:
# model: AdaBoostClassifier(random_state=72)
# Score: [0.99372385 0.98640167 0.99058577 0.99267782 0.99058577 0.99267782
#  0.98535565 0.98010471 0.99057592 0.98429319]
# Mean score: 0.9886982190190367
# Standard deviation: 0.0042104923629177875

# %% [markdown]
# ### Cross validate the GradientBoostingClassifier()

# %%
score=cross_val_score(gd,x,y,cv=10,scoring='accuracy')
print("model:",gd)
print("Score:",score)
print("Mean score:",score.mean())
print("Standard deviation:",score.std())
# Out:
# model: GradientBoostingClassifier(max_features='auto', random_state=72)
# Score: [0.99267782 0.99267782 0.98953975 0.99372385 0.9916318  0.98640167
#  0.98430962 0.98743455 0.9895288  0.98848168]
# Mean score: 0.9896407369274245
# Standard deviation: 0.002902234122529476

# %% [markdown]
# ### Cross validate the BaggingClassifier()

# %%
score=cross_val_score(bc,x,y,cv=10,scoring='accuracy')
print("model:",bc)
print("Score:",score)
print("Mean score:",score.mean())
print("Standard deviation:",score.std())
# Out:
# model: BaggingClassifier(random_state=72)
# Score: [0.99790795 0.98953975 0.99058577 0.99372385 0.99372385 0.9874477
#  0.98640167 0.98429319 0.99162304 0.98848168]
# Mean score: 0.9903728449692217
# Standard deviation: 0.0038262775195774946

# %% [markdown]
# ### Cross validate the ExtraTreesClassifier()

# %%
score=cross_val_score(ec,x,y,cv=10,scoring='accuracy')
print("model:",ec)
print("Score:",score)
print("Mean score:",score.mean())
print("Standard deviation:",score.std())
# Out:
# model: ExtraTreesClassifier(random_state=72)
# Score: [0.98640167 0.97175732 0.97803347 0.98640167 0.97803347 0.97594142
#  0.96338912 0.97801047 0.98534031 0.97696335]
# Mean score: 0.978027229512147
# Standard deviation: 0.006729134950092045

# %% [markdown]
# ### Cross validate the DecisionTreeClassifier()

# %%
score=cross_val_score(dtc,x,y,cv=10,scoring='accuracy')
print("model:",dtc)
print("Score:",score)
print("Mean score:",score.mean())
print("Standard deviation:",score.std())
# Out:
# model: DecisionTreeClassifier(random_state=72)
# Score: [0.98953975 0.98221757 0.98535565 0.98535565 0.98953975 0.98640167
#  0.9832636  0.98534031 0.98638743 0.98115183]
# Mean score: 0.9854553221319197
# Standard deviation: 0.0026262005018974823

# %% [markdown]
# ### Among all three models RandomForestClassifier() gives highest score so we adopt Gaussian NB as our Final Model

# %% [markdown]
# ### Plotting Confusion matrix for RandomForestClassifier()

# %%
cm=confusion_matrix(y_test,predrf)
sns.heatmap(cm,annot=True,cbar=False,cmap='coolwarm')

plt.title("Confusion Matrix of RandomForestClassifier")
plt.show()

# %% [markdown]
# # Auc_Roc Curve and finding auc score

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
y_pred_prob=rf.predict_proba(x_test)[:,1]
fpr,tpr,thredholds=roc_curve(y_test,y_pred_prob)
plt.plot([0,1],[0,1],'k--')
plt.plot(fpr,tpr,label='Random Forest Classifier')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('RandomForestClassifier')
plt.show()

auc_score=roc_auc_score(y_test,predrf)
print(auc_score)
# Out:
# 0.9890502796966204

# %% [markdown]
# # Saving the model

# %%
import joblib

# %% [markdown]
# # Save the model as a pickle in a file

# %%
joblib.dump(rf,'skyserver.pkl')
# Out:
# ['skyserver.pkl']
